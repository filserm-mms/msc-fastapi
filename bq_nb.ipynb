# %% [markdown]
# <a href="https://colab.research.google.com/github/filserm-mms/msc-fastapi/blob/main/bq_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.oauth2 import service_account
key_path = os.environ['GOOGLE_APPLICATION_CREDENTIALS']
credentials = service_account.Credentials.from_service_account_file(
                                            key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
                        )
print (credentials)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2469604a4225> in <module>()
#       1 import os
#       2 from google.oauth2 import service_account
# ----> 3 key_path = os.environ['GOOGLE_APPLICATION_CREDENTIALS']
#       4 credentials = service_account.Credentials.from_service_account_file(
#       5                                             key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
#
# /usr/lib/python3.7/os.py in __getitem__(self, key)
#     679         except KeyError:
#     680             # raise KeyError with the original key value
# --> 681             raise KeyError(key) from None
#     682         return self.decodevalue(value)
#     683
#
# KeyError: 'GOOGLE_APPLICATION_CREDENTIALS'
